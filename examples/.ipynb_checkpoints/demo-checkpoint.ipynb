# %%
using Pkg: activate
activate("../")

using LinearAlgebra
using WAV
using Plots


using Revise
using SpeechFeatures
using ExpFamilyDistributions
using MarkovModels
using ConvHMM
# Out:
#  Activating environment at `~/GithubRepositories/ConvHMM/Project.toml`
# ┌ Info: Precompiling ConvHMM [5d1d1fbc-085f-4091-a392-00dfde59b78b]
# └ @ Base loading.jl:1278

# %%
using Base.Filesystem: isfile
if ! isfile("LDC93S1.wav")
    run(`wget https://catalog.ldc.upenn.edu/desc/addenda/LDC93S1.wav`)
end

if ! isfile("LDC93S1.phn")
    run(`wget https://catalog.ldc.upenn.edu/desc/addenda/LDC93S1.phn`)
end

# %%
channels, srate = wavread("LDC93S1.wav", format="double")
channels *= typemax(Int16)
s = channels[:, 1]

println("sampling freq: $srate Hz\nduration: $(round(length(s) / srate, digits=2)) s")

logfbank = LogMelSpectrum(
    fftlen = fftlen_auto,
    srate = 16000,
    frameduration = 0.025,
    framestep = 0.01,
    removedc = true,
    preemphasis = 0.97,
    dithering = 0.,
    windowfn = hann,
    windowpower = 1.0,
    nfilters = 26,
    lofreq = 80,
    hifreq = 8000
)

X = s |> logfbank
heatmap(
    Vector(range(0, length(s) / srate, length=size(X, 2))),
    1:size(X, 1),
    X,
    size = (900, 200),
    xlabel = "time (s)",
    ylabel = "Filter bank index",
    c = :viridis
)
# Out:
# sampling freq: 16000.0 Hz
# duration: 2.92 s

# %%
phones = Set{String}()
trans = String[]
open("LDC93S1.phn") do f
    for line in eachline(f)
        phn = split(line)[3]
        push!(phones, phn)
        push!(trans, phn)
    end
end

emissionsmap = Dict(phn => i for (i, phn) in enumerate(phones))
# Out:
# Dict{String,Int64} with 26 entries:
#   "ix"  => 1
#   "kcl" => 2
#   "sh"  => 3
#   "r"   => 4
#   "jh"  => 5
#   "en"  => 6
#   "ux"  => 7
#   "gcl" => 8
#   "eh"  => 9
#   "epi" => 10
#   "q"   => 11
#   "h#"  => 12
#   "s"   => 13
#   "d"   => 14
#   "dx"  => 15
#   "ah"  => 16
#   "g"   => 17
#   "w"   => 18
#   "hv"  => 19
#   "ih"  => 20
#   "k"   => 21
#   "ao"  => 22
#   "axr" => 23
#   "y"   => 24
#   "l"   => 25
#   "dcl" => 26

# %%
function makehmm(nstates, pdfindex)
    fsm = FSM()
    prev = initstate(fsm)
    for i in 1:nstates
        s = addstate!(fsm, pdfindex = pdfindex)
        link!(fsm, prev, s)
        link!(fsm, s, s)
        prev = s
    end
    link!(fsm, prev, finalstate(fsm))
    fsm |> weightnormalize!
end

hmms = Dict(phone => makehmm(3, i) for (i, phone) in enumerate(phones));

# %%
fsm = LinearFSM(trans)
# Out:
# FSM(MarkovModels.StateIDCounter(37), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},State}(18 => State(18, label = gcl),30 => State(30, label = dx),33 => State(33, label = l),32 => State(32, label = ao),finalstateid => State(finalstateid),2 => State(2, label = sh),16 => State(16, label = q),11 => State(11, label = ah),21 => State(21, label = ix),7 => State(7, label = jh)…), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},Array{Link,1}}(18 => [Link{Float64}(State(18, label = gcl), State(19, label = g), 0.0)],30 => [Link{Float64}(State(30, label = dx), State(31, label = axr), 0.0)],33 => [Link{Float64}(State(33, label = l), State(34, label = y), 0.0)],32 => [Link{Float64}(State(32, label = ao), State(33, label = l), 0.0)],2 => [Link{Float64}(State(2, label = sh), State(3, label = ix), 0.0)],16 => [Link{Float64}(State(16, label = q), State(17, label = en), 0.0)],11 => [Link{Float64}(State(11, label = ah), State(12, label = kcl), 0.0)],21 => [Link{Float64}(State(21, label = ix), State(22, label = s), 0.0)],7 => [Link{Float64}(State(7, label = jh), State(8, label = ih), 0.0)],9 => [Link{Float64}(State(9, label = dcl), State(10, label = d), 0.0)]…), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},Array{Link,1}}(18 => [Link{Float64}(State(18, label = gcl), State(17, label = en), 0.0)],30 => [Link{Float64}(State(30, label = dx), State(29, label = ao), 0.0)],33 => [Link{Float64}(State(33, label = l), State(32, label = ao), 0.0)],32 => [Link{Float64}(State(32, label = ao), State(31, label = axr), 0.0)],finalstateid => [Link{Float64}(State(finalstateid), State(37, label = h#), 0.0)],2 => [Link{Float64}(State(2, label = sh), State(1, label = h#), 0.0)],16 => [Link{Float64}(State(16, label = q), State(15, label = ux), 0.0)],11 => [Link{Float64}(State(11, label = ah), State(10, label = d), 0.0)],21 => [Link{Float64}(State(21, label = ix), State(20, label = r), 0.0)],7 => [Link{Float64}(State(7, label = jh), State(6, label = dcl), 0.0)]…))

# %%
align = fsm ∘ hmms |> removenilstates!
# Out:
# FSM(MarkovModels.StateIDCounter(222), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},State}(finalstateid => State(finalstateid),134 => State(134, label = s),160 => State(160, pdfindex = 1),215 => State(215, pdfindex = 25),131 => State(131, pdfindex = 20),207 => State(207, pdfindex = 23),74 => State(74, label = ix),201 => State(201, pdfindex = 10),176 => State(176, pdfindex = 4),57 => State(57, pdfindex = 22)…), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},Array{Link,1}}(134 => [Link{Float64}(State(134, label = s), State(182, pdfindex = 1), 0.0)],160 => [Link{Float64}(State(160, pdfindex = 1), State(161, pdfindex = 1), -0.6931471805599453), Link{Float64}(State(160, pdfindex = 1), State(160, pdfindex = 1), -0.6931471805599453)],215 => [Link{Float64}(State(215, pdfindex = 25), State(216, pdfindex = 25), -0.6931471805599453), Link{Float64}(State(215, pdfindex = 25), State(215, pdfindex = 25), -0.6931471805599453)],131 => [Link{Float64}(State(131, pdfindex = 20), State(129, label = ih), -0.6931471805599453), Link{Float64}(State(131, pdfindex = 20), State(131, pdfindex = 20), -0.6931471805599453)],207 => [Link{Float64}(State(207, pdfindex = 23), State(205, pdfindex = 23), -0.6931471805599453), Link{Float64}(State(207, pdfindex = 23), State(207, pdfindex = 23), -0.6931471805599453)],74 => [Link{Float64}(State(74, label = ix), State(137, pdfindex = 13), 0.0)],201 => [Link{Float64}(State(201, pdfindex = 10), State(199, label = epi), -0.6931471805599453), Link{Float64}(State(201, pdfindex = 10), State(201, pdfindex = 10), -0.6931471805599453)],176 => [Link{Float64}(State(176, pdfindex = 4), State(174, label = r), -0.6931471805599453), Link{Float64}(State(176, pdfindex = 4), State(176, pdfindex = 4), -0.6931471805599453)],57 => [Link{Float64}(State(57, pdfindex = 22), State(55, pdfindex = 22), -0.6931471805599453), Link{Float64}(State(57, pdfindex = 22), State(57, pdfindex = 22), -0.6931471805599453)],70 => [Link{Float64}(State(70, pdfindex = 16), State(71, pdfindex = 16), -0.6931471805599453), Link{Float64}(State(70, pdfindex = 16), State(70, pdfindex = 16), -0.6931471805599453)]…), Dict{Union{MarkovModels.FinalStateID, MarkovModels.InitStateID, Int64},Array{Link,1}}(finalstateid => [Link{Float64}(State(finalstateid), State(154, label = h#), 0.0)],134 => [Link{Float64}(State(134, label = s), State(136, pdfindex = 13), -0.6931471805599453)],160 => [Link{Float64}(State(160, pdfindex = 1), State(160, pdfindex = 1), -0.6931471805599453), Link{Float64}(State(160, pdfindex = 1), State(162, pdfindex = 1), -0.6931471805599453)],215 => [Link{Float64}(State(215, pdfindex = 25), State(215, pdfindex = 25), -0.6931471805599453), Link{Float64}(State(215, pdfindex = 25), State(217, pdfindex = 25), -0.6931471805599453)],131 => [Link{Float64}(State(131, pdfindex = 20), State(130, pdfindex = 20), -0.6931471805599453), Link{Float64}(State(131, pdfindex = 20), State(131, pdfindex = 20), -0.6931471805599453)],207 => [Link{Float64}(State(207, pdfindex = 23), State(207, pdfindex = 23), -0.6931471805599453), Link{Float64}(State(207, pdfindex = 23), State(114, label = ih), 0.0)],74 => [Link{Float64}(State(74, label = ix), State(76, pdfindex = 1), -0.6931471805599453)],201 => [Link{Float64}(State(201, pdfindex = 10), State(200, pdfindex = 10), -0.6931471805599453), Link{Float64}(State(201, pdfindex = 10), State(201, pdfindex = 10), -0.6931471805599453)],176 => [Link{Float64}(State(176, pdfindex = 4), State(175, pdfindex = 4), -0.6931471805599453), Link{Float64}(State(176, pdfindex = 4), State(176, pdfindex = 4), -0.6931471805599453)],57 => [Link{Float64}(State(57, pdfindex = 22), State(57, pdfindex = 22), -0.6931471805599453), Link{Float64}(State(57, pdfindex = 22), State(194, label = axr), 0.0)]…))

# %%
S = length(phones)
D = size(X, 1)
K = 5
μ₀ = zeros(Float64, K+1)
Σ₀ = Matrix{Float64}(I, K+1, K+1)
a₀ = 1
b₀ = 1
models = [[ARNormal1D(K, μ₀, Σ₀, a₀, b₀) for i in 1:S] for d in 1:D];

# %%
epochs = 10

elbos = []
for e in 1:epochs
    # E-step 
    lnαβ, totllh = αβrecursion(align, models(X), pruning = nopruning)
    γ = resps(align, lnαβ, dense = true)
    
    KL = 0.
    for d in 1:length(models)
        for m in models[d]
            KL += kldiv(m.hposterior, m.hprior)
            KL += kldiv(m.λposterior, m.λprior)
        end
    end
    push!(elbos, (totllh - KL) / length(X))
    
    # M-step
    #if e % 2 == 1
    update_h!(models, X, γ)
    #else
    update_λ!(models, X, γ)
    #end
end

plot(elbos)

# %%
elbos
# Out:
# 10-element Array{Any,1}:
#  -172.8276713003345
#    -0.6855199678943033
#    -0.4325415037303223
#    -0.39155204252054426
#    -0.38316743226400435
#    -0.3797718799953104
#    -0.3769978143238714
#    -0.3744508019082692
#    -0.3723465629164519
#    -0.3722955175728616

# %%
lnαβ, totllh = αβrecursion(align, models(X))
γ = resps(align, lnαβ, dense = true)
heatmap(γ)

# %%
t, prec = trajectory(models[d], X[d, :], γ)
t
# Out:
# 290-element Array{Float64,1}:
#  1.2137827240422823
#  1.9783250157542553
#  2.1852301417446194
#  2.1843871022198114
#  2.1165412209316132
#  2.0631956844764816
#  2.1254900437308066
#  2.1650175205220097
#  2.1351305882830967
#  2.088742567924837
#  2.0601240050562892
#  1.608780438089915
#  2.360384124453086
#  ⋮
#  5.12993188805307
#  4.868000887419954
#  4.636184969801667
#  4.175964060078196
#  2.64122800492395
#  2.2544616712673955
#  2.190626440846645
#  1.8327321529820484
#  1.7512824731255119
#  1.8264087289461113
#  1.547550257220482
#  1.8519049937183676

# %%
sqrt.(1/prec)
# Out:
# 1×290 Array{Float64,2}:
#  0.00629192  0.00629192  0.00629192  …  0.00629192  0.00629192  0.00629192

# %%
d = 1
t, prec = trajectory(models[d], X[d, :], γ)

plot(
    1:size(X, 2), 
    X[d, :],
    size = (900, 200),
    label = "x"
)
plot!(
    1:size(X, 2), 
    t,
    ribbon = sqrt.(1 ./ prec),
    fillalpha = 0.2,
    size = (900, 500),
    label = "μₜ",
    color = :green
)

# %%
d = 1
t, prec = trajectory(models[d], X[d, :], γ)

plot(
    1:size(X, 2), 
    X[d, :],
    size = (900, 200),
    label = "x"
)
plot!(
    1:size(X, 2), 
    t,
    ribbon = sqrt.(1 ./ prec),
    fillalpha = 0.2,
    size = (900, 500),
    label = "μₜ"
)
